# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv('salary_data_cleaned.csv')
df.head()
# Out:
#                    Job Title              Salary Estimate  \
# 0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2             Data Scientist   $80K-$90K (Glassdoor est.)
# 3             Data Scientist   $56K-$97K (Glassdoor est.)
# 4             Data Scientist  $86K-$143K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# 1  University of Maryland Medical System\n3.4    Linthicum, MD
# ...

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary',
#        'average_salary', 'company_txt', 'job_state', 'same_state', 'age',
#        'python', 'r_studio', 'spark', 'aws', 'excel'],
#       dtype='object')

# %%
def title_simplifier(title):
    if 'data scientist' in title.lower():
        return 'data scientist'
    elif 'data engineer' in title.lower():
        return 'data engineer'
    elif 'analyst' in title.lower():
        return 'analyst'
    elif 'machine learning' in title.lower():
        return 'mle'
    elif 'manager' in title.lower():
        return 'manager'
    elif 'director' in title.lower():
        return 'director'
    else:
        return 'na'
    
def seniority(title):
    if 'sr' in title.lower() or 'senior' in title.lower() or 'sr' in title.lower() or 'lead' in title.lower() or 'principal' in title.lower():
            return 'senior'
    elif 'jr' in title.lower() or 'jr.' in title.lower():
        return 'jr'
    else:
        return 'na'

# %% [markdown]
# ## Job title and seniority

# %%
df['job_simp'] = df['Job Title'].apply(title_simplifier)
df.job_simp.value_counts()
# Out:
# data scientist    279
# na                184
# data engineer     119
# analyst           102
# manager            22
# mle                22
# director           14
# Name: job_simp, dtype: int64

# %%
df['seniorty'] = df['Job Title'].apply(seniority)
df.seniorty.value_counts()
# Out:
# na        520
# senior    220
# jr          2
# Name: seniorty, dtype: int64

# %% [markdown]
# ##  Fix state Los Angeles

# %%
df['job_state'] = df.job_state.apply(lambda x: x.strip() if x.strip().lower() != 'los angeles' else 'CA')
df.job_state.value_counts()
# Out:
# CA    152
# MA    103
# NY     72
# VA     41
# IL     40
# MD     35
# PA     33
# TX     28
# NC     21
# WA     21
# NJ     17
# FL     16
# OH     14
# TN     13
# DC     11
# CO     11
# WI     10
# UT     10
# IN     10
# AZ      9
# MO      9
# AL      8
# GA      6
# DE      6
# KY      6
# MI      6
# CT      5
# IA      5
# LA      4
# OR      4
# NE      4
# NM      3
# KS      3
# ID      2
# MN      2
# RI      1
# SC      1
# Name: job_state, dtype: int64

# %% [markdown]
# ##  Job description length

# %%
df['desc_len'] = df['Job Description'].apply(lambda x: len(x))
df['desc_len']
# Out:
# 0      2536
# 1      4783
# 2      3461
# 3      3883
# 4      2728
#        ...
# 737    6162
# 738    6130
# 739    3078
# 740    1642
# 741    3673
# Name: desc_len, Length: 742, dtype: int64

# %% [markdown]
# ##  Competitor count

# %%
df['num_comp'] = df['Competitors'].apply(lambda x: len(x.split(',')) if x != '-1' else 0)

# %%
df.num_comp
# Out:
# 0      0
# 1      0
# 2      0
# 3      3
# 4      3
#       ..
# 737    3
# 738    3
# 739    0
# 740    0
# 741    0
# Name: num_comp, Length: 742, dtype: int64

# %% [markdown]
# ## Hourly wage to annual

# %%
df['min_salary'] = df.apply(lambda x: x.min_salary*2 if x.hourly == 1 else x.min_salary, axis=1)
df['max_salary'] = df.apply(lambda x: x.max_salary*2 if x.hourly == 1 else x.max_salary, axis=1)
df[df.hourly == 1][['hourly', 'min_salary', 'max_salary']]
# Out:
#      hourly  min_salary  max_salary
# 165       1          34          48
# 177       1          42          68
# 197       1          36          50
# 202       1          42          68
# 210       1          30          50
# 246       1          34          48
# 271       1          42          68
# 337       1          36          50
# 345       1          48          78
# 357       1          42          68
# 363       1          50          56
# 408       1          42          58
# 409       1          20          34
# 492       1          36          50
# 509       1          48          78
# 533       1          42          68
# 542       1          50          56
# 617       1          42          58
# 618       1          20          34
# 645       1          54          94
# 666       1          36          50
# 682       1          48          78
# 711       1          42          68
# 724       1          50          56

# %% [markdown]
# ## remove new line from job title

# %%
df['company_txt'] = df.company_txt.apply(lambda x: x.replace('\n', ''))
df['company_txt']
# Out:
# 0                          tecolote research
# 1      university of maryland medical system
# 2                                    knowbe4
# 3                                       pnnl
# 4                         affinity solutions
#                         ...
# 737                                      gsk
# 738                               eventbrite
# 739           software engineering institute
# 740                             numeric, llc
# 741             riverside research institute
# Name: company_txt, Length: 742, dtype: object

# %% [markdown]
# ## Some Hist and plots

# %%
df.describe().T
# Out:
#                    count         mean          std    min     25%     50%  \
# Rating             742.0     3.618868     0.801210   -1.0     3.3     3.7
# Founded            742.0  1837.154987   497.183763   -1.0  1939.0  1988.0
# hourly             742.0     0.032345     0.177034    0.0     0.0     0.0
# employer_provided  742.0     0.022911     0.149721    0.0     0.0     0.0
# min_salary         742.0    74.719677    30.980593   15.0    52.0    69.5
# max_salary         742.0   128.149596    45.220324   16.0    96.0   124.0
# average_salary     742.0   100.626011    38.855948   13.5    73.5    97.5
# same_state         742.0     0.557951     0.496965    0.0     0.0     1.0
# age                742.0    46.591644    53.778815   -1.0    11.0    24.0
# python             742.0     0.528302     0.499535    0.0     0.0     1.0
# r_studio           742.0     0.001348     0.036711    0.0     0.0     0.0
# spark              742.0     0.225067     0.417908    0.0     0.0     0.0
# ...

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary',
#        'average_salary', 'company_txt', 'job_state', 'same_state', 'age',
#        'python', 'r_studio', 'spark', 'aws', 'excel', 'job_simp', 'seniorty',
#        'desc_len', 'num_comp'],
#       dtype='object')

# %%
df.Rating.hist();

# %%
df.average_salary.hist();

# %%
df.age.hist();

# %%
df.desc_len.hist();

# %%
df.boxplot(column=['age', 'average_salary', 'Rating']);

# %%
df.boxplot(column='Rating');

# %%
corr = df[['age', 'average_salary', 'Rating', 'desc_len', 'num_comp']].corr()
corr
# Out:
#                      age  average_salary    Rating  desc_len  num_comp
# age             1.000000        0.019655  0.021655  0.163911  0.126687
# average_salary  0.019655        1.000000  0.013492  0.078808  0.093813
# Rating          0.021655        0.013492  1.000000 -0.012281  0.027190
# desc_len        0.163911        0.078808 -0.012281  1.000000  0.104620
# num_comp        0.126687        0.093813  0.027190  0.104620  1.000000

# %%
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(corr, vmax=3, center=0, cmap=cmap, square=True, linewidths=1, cbar_kws={'shrink': 1});

# %%
df_cat = df[['Location', 'Headquarters', 'Size', 'Type of ownership', 'Industry', 'Sector', 'Revenue', 'company_txt', 'job_state', 'same_state', 
    'python', 'r_studio', 'spark', 'aws', 'excel', 'job_simp', 'seniorty']]

# %%
for i in df_cat.columns:
    cat_num = df_cat[i].value_counts()
    #print('Graph for %s: total = %d' % (i, len(cat_num)))
    print(f'Graph for {i}: total = {len(cat_num)}')
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# Graph for Location: total = 200
# Graph for Headquarters: total = 198
# Graph for Size: total = 9
# Graph for Type of ownership: total = 11
# Graph for Industry: total = 60
# Graph for Sector: total = 25
# Graph for Revenue: total = 14
# Graph for company_txt: total = 343
# Graph for job_state: total = 37
# Graph for same_state: total = 2
# Graph for python: total = 2
# Graph for r_studio: total = 2
# Graph for spark: total = 2
# Graph for aws: total = 2
# Graph for excel: total = 2
# Graph for job_simp: total = 7
# Graph for seniorty: total = 3

# %%
for i in df_cat[['Location', 'Headquarters', 'company_txt']].columns:
    cat_num = df_cat[i].value_counts()[:20]
    print(f'Graph for {i}: total = {len(cat_num)}')
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# Graph for Location: total = 20
# Graph for Headquarters: total = 20
# Graph for company_txt: total = 20

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary',
#        'average_salary', 'company_txt', 'job_state', 'same_state', 'age',
#        'python', 'r_studio', 'spark', 'aws', 'excel', 'job_simp', 'seniorty',
#        'desc_len', 'num_comp'],
#       dtype='object')

# %%
pd.pivot_table(df, index='job_simp', values=['average_salary', 'max_salary', 'min_salary'])
# Out:
#                 average_salary  max_salary  min_salary
# job_simp
# analyst              65.857843   85.215686   47.029412
# data engineer       105.403361  134.655462   76.151261
# data scientist      117.564516  145.247312   89.881720
# director            168.607143  208.214286  129.000000
# manager              84.022727  109.954545   58.090909
# mle                 126.431818  162.500000   90.363636
# na                   84.853261  113.793478   62.141304

# %%
pd.pivot_table(df, index=['job_simp', 'seniorty'], values='average_salary')
# Out:
#                          average_salary
# job_simp       seniorty
# analyst        jr             56.500000
#                na             61.155405
#                senior         79.092593
# data engineer  na             96.701220
#                senior        124.689189
# data scientist jr            106.500000
#                na            107.043011
#                senior        138.956522
# director       na            168.607143
# manager        na             84.022727
# mle            na            119.133333
#                senior        142.071429
# na             na             73.988189
#                senior        109.061404

# %%
pd.set_option('display.max_rows', None)

# %%
pd.pivot_table(df, index=['job_state', 'job_simp'], values='average_salary').sort_values('job_state', ascending=False)
# Out:
#                           average_salary
# job_state job_simp
# WI        na                   54.000000
#           data scientist      113.500000
#           analyst              58.833333
# WA        na                   97.500000
#           data scientist       99.764706
#           analyst              54.500000
# VA        na                   79.300000
#           mle                  87.000000
#           data scientist      108.416667
#           data engineer        96.900000
#           analyst              71.583333
# UT        data engineer       100.333333
#           analyst              54.750000
#           data scientist      140.500000
# TX        na                   41.285714
#           data scientist      100.730769
#           data engineer       113.062500
# TN        data scientist       96.000000
#           data engineer       100.950000
#           analyst              13.500000
# SC        na                   60.500000
# ...

# %%
pd.pivot_table(df, index=['job_state', 'job_simp'], values='average_salary', aggfunc='count').sort_values('job_state', ascending=False)
# Out:
#                           average_salary
# job_state job_simp
# WI        na                           4
#           data scientist               3
#           analyst                      3
# WA        na                           1
#           data scientist              17
#           analyst                      3
# VA        na                           5
#           mle                          2
#           data scientist              18
#           data engineer               10
#           analyst                      6
# UT        data engineer                3
#           analyst                      4
#           data scientist               3
# TX        na                           7
#           data scientist              13
#           data engineer                8
# TN        data scientist               1
#           data engineer               10
#           analyst                      2
# SC        na                           1
# ...

# %%
pd.pivot_table(df[df.job_simp == 'data scientist'], index='job_state', values='average_salary').sort_values('average_salary', ascending=False)
# Out:
#            average_salary
# job_state
# DC             149.000000
# CA             142.522059
# UT             140.500000
# MO             127.666667
# IL             117.233333
# NC             117.000000
# NY             115.250000
# MA             113.750000
# WI             113.500000
# PA             113.333333
# MD             109.115385
# CO             108.666667
# VA             108.416667
# NJ             106.875000
# MI             106.625000
# OH             105.285714
# TX             100.730769
# WA              99.764706
# OR              98.500000
# FL              97.357143
# TN              96.000000
# IN              84.500000
# KY              84.000000
# CT              84.000000
# GA              81.333333
# NM              74.333333
# AZ              69.500000

# %%
# rating, industry, sector, revenue, number of competitors, hourly, employer provided, pyhthon, r, spark, aws, excel, desc_len, type of ownership

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary',
#        'average_salary', 'company_txt', 'job_state', 'same_state', 'age',
#        'python', 'r_studio', 'spark', 'aws', 'excel', 'job_simp', 'seniorty',
#        'desc_len', 'num_comp'],
#       dtype='object')

# %%
df_pivots = df[['Rating', 'Industry', 'Sector', 'Revenue', 'Competitors', 'hourly', 'employer_provided', 'python', 'r_studio', 'spark', 'aws', 'excel', 'Type of ownership', 'average_salary']]

# %%
pd.set_option('display.max_rows', None)

# %%
for i in df_pivots.columns:
    print(i)
    print(pd.pivot_table(df_pivots, index=i, values='average_salary').sort_values('average_salary', ascending=False))
# Out:
# Rating
#         average_salary
# Rating
# -1.0        136.181818
#  5.0        134.700000
#  2.5        120.000000
#  4.5        117.714286
#  4.1        116.368421
#  3.9        113.071429
#  2.6        109.083333
#  4.4        108.606061
#  3.2        105.500000
#  4.0        105.340426
#  3.5        104.897959
#  3.7        104.131148
#  4.7        103.983871
#  4.3        102.468750
#  3.3        101.858974
#  4.2        100.442308
#  2.2         97.750000
#  4.6         97.250000
#  3.8         96.811475
#  2.1         95.900000
#  3.4         93.011364
#  1.9         87.500000
#  3.1         86.580000
#  3.0         85.588235
#  3.6         85.467391
#  2.8         83.928571
#  2.7         83.250000
#  2.3         81.500000
#  2.9         81.138889
#  4.8         80.277778
#  2.4         60.214286
# Industry
#                                           average_salary
# Industry
# Other Retail Stores                           163.500000
# ...

# %%
pd.pivot_table(df_pivots, index='Revenue', columns='python', values='average_salary', aggfunc='count')
# Out:
# python                               0      1
# Revenue
# $1 to $2 billion (USD)            16.0   44.0
# $1 to $5 million (USD)             1.0    7.0
# $10 to $25 million (USD)          16.0   16.0
# $10+ billion (USD)                66.0   58.0
# $100 to $500 million (USD)        47.0   44.0
# $2 to $5 billion (USD)            17.0   22.0
# $25 to $50 million (USD)          24.0   16.0
# $5 to $10 billion (USD)            9.0   10.0
# $5 to $10 million (USD)            9.0    9.0
# $50 to $100 million (USD)         21.0   25.0
# $500 million to $1 billion (USD)  29.0   28.0
# -1                                 1.0    NaN
# Less than $1 million (USD)         1.0    3.0
# Unknown / Non-Applicable          93.0  110.0
